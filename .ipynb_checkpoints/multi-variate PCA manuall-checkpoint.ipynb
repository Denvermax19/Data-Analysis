# %%
from default_libs import *

# %%
from sklearn.datasets import load_digits

# %% [markdown]
# ## Load the dataset

# %%
digits=load_digits()
images=digits.data
labels=digits.target # labels 0 to 9

# %% [markdown]
# ## Standardize the data

# %%
import numpy as np

# %%
mean=np.mean(images.T, axis=1)

centered_data=mean-images

# %% [markdown]
# ## Compute co-variance matrix

# %%
covariance_matrix=np.cov(centered_data.T, rowvar=False)

# %% [markdown]
# ## Compute EigenValues and EigenVectors

# %%
eigenvalues, eigenvectors=np.linalg.eig(covariance_matrix)

# %% [markdown]
# ## Sort the eigenvalues and eigenvectors

# %%
sorted_indices = np.argsort(eigenvalues)[::-1]
sorted_eigenvalues = eigenvalues[sorted_indices]
sorted_eigenvectors = eigenvectors[:, sorted_indices]

# %% [markdown]
# ## Select the Top k Components

# %%
k = 10
top_k_eigenvectors = sorted_eigenvectors[:, :k]

# %% [markdown]
# ## Project Data into Lower-Dimensional Space

# %%
# Project the data onto the new feature space
projected_data = centered_data.dot(top_k_eigenvectors)

# %%
# Display the shape of the projected data
print("Shape of projected data:", projected_data.shape)
# Out:
# Shape of projected data: (1797, 10)
