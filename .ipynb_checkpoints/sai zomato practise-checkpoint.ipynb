# %%
from default_libs import *

# %%
df=pd.read_csv(r"C:\Users\lette\Data Analytics\Data Visualization\Zomato-data-.csv")

# %%
df.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.rename(columns={'approx_cost(for two people)':'cost for couples'},inplace=True)

# %%
def rate_clean(value):
    value=str(value).split('/')
    value=value[0]
    return float(value)

df['rate']=df['rate'].apply(rate_clean)

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    cost for couples listed_in(type)
# 0               800          Buffet
# 1               800          Buffet
# 2               800          Buffet
# 3               300          Buffet
# 4               600          Buffet

# %%
df.rename(columns={'listed_in(type)':'restaurant type'}, inplace=True)

# %%
df.describe()
# Out:
#              rate        votes  cost for couples
# count  148.000000   148.000000        148.000000
# mean     3.633108   264.810811        418.243243
# std      0.402271   653.676951        223.085098
# min      2.600000     0.000000        100.000000
# 25%      3.300000     6.750000        200.000000
# 50%      3.700000    43.500000        400.000000
# 75%      3.900000   221.750000        600.000000
# max      4.600000  4884.000000        950.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure()
sns.countplot(x=df['online_order'],color='pink')
plt.savefig('online order sai.jpg',dpi=300)
plt.show()

# %%
sns.kdeplot(x=df['cost for couples'],color='orange',fill=True)
plt.show()

# %%
df['cost for couples'].skew()
# Out:
# np.float64(0.5002940102488174)

# %%
df['votes'].nlargest(5)
# Out:
# 38    4884
# 86    4401
# 7     2556
# 44    2556
# 65    1720
# Name: votes, dtype: int64

# %%
df['votes'].nsmallest(5)
# Out:
# 72    0
# 75    0
# 84    0
# 90    0
# 91    0
# Name: votes, dtype: int64

# %%
df['votes'].between(0,50).sum()
# Out:
# np.int64(76)
